# %% [markdown]
# # Экспериментальная база специальной теории относительности.
#
# В галилеевских преобразованиях время является абсолютной величиной. Оно не зависит от выбора системы отсчета.
#
# Все хорошо работает до того момента, пока относительные скорости малы.
#
# Ключевой величиной здесь является (в СТО): скорость света, которая имеет конечное значение.
#
#
# **Постулаты СТО:**
# 1. Все законы природы инвариантны относительно выбора ИСО (принцип относительности Эйнштейна).
# 2. Свет распространяется в вакууме в любой ИСО с определенной скоростью, которая не зависит ни от скорости источника, ни от скорости наблюдателя (скорость света в вакууме одинакова во всех ИСО и является максимальной скоростью передачи информации).
#
# **Небольшое замечание :** Скорость света не является максимальной скоростью в природе, она является лишь максимальной скоростью передачи информации. Например, "солнечный зайчик" вполне себе может двигаться со скоростью быстрее скорости света.
#
#  **Олаф (Оле) Рёмер и Жан Пикар.** Затмение спутника ИО. Ураниборг (рядом с Копенгагеном). Рёмер изучил данные Кассини. (Наблюдали за затмениями спутника своей планеты).
#
#  Рёмер: время между затмениями ИО уменьшается, когда Земля приближается к Юпитеру. Почему?
#
#  Пусть $t_1$ и $t_2$ - время начала и конца затмения. Тогда на Земле эти события будут иметь времена: (Доклад 1676 года)
#
# <br>
#
#  \begin{align}
#     &t_{\text{з1}}\;=\;t_1\;+\;\dfrac{l_1}{c},\; -\; \text{где} \; l_1 \; -\; dist\;(\text{Земля - Юпитер в начальный момент времени}). \nonumber \\
#     &t_{\text{з2}}\;=\;t_2\;+\;\dfrac{l_2}{c},\; -\; \text{где} \; l_2 \; -\; dist\;(\text{Земля - Юпитер в конечный момент времени}). \nonumber \\
#     &\Rightarrow T_{\text{з}}\;=\;t_{\text{з2}}\;-\;t_{\text{з1}}\;=\;T\;+\;\dfrac{l_2 - l_1}{c}, \nonumber \\
#     &\Rightarrow \text{приближаемся} \Rightarrow l_2\;<\;l_1 \Rightarrow T_{\text{з}}\;<\;T. \nonumber
# \end{align}
#
# <br>
#
# (Период между вхождениями в область тени)
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/lecture_16_Zatmenie_sputnika.png" width="400" align="center"/>
#         <figcaption>Рис. 16.1: Затмение спутника ИО.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# Рёмер вычислил: $\sim$ 220000 $\frac{\text{км}}{\text{с}}$.
#
# **Опыт Физо**. В 1851 году.
#
# Решил в качестве затвора использовать зубчатое колесо.
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/lecture_16_opyt_fizo.png" width="400" align="center"/>
#         <figcaption>Рис. 16.2: Опыт Физо.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# $v\;=\;\omega R;\; v\;=\;\frac{2\pi R}{T};\; \Delta \varphi \;=\; \omega \Delta t$
# Условие исчезновения луча у наблюдателя (за время, пока луч света проходит путь до зеркала и обратно - $2L$, зубчатое колесо поворачивается ровно на один зубец - луч, изначально прошедший через дырку между зубцами, на обратном пути попадает на зубец и не доходит до наблюдателя):
#
# <br>
#
# \begin{align}
#     &\Delta t \;=\;\dfrac{2L}{c}\;=\;\dfrac{\Delta \varphi}{\omega}. \nonumber
# \end{align}
# $\Delta \varphi$ - угол дуги, которая совпадает с величиной зубца.
# $\Rightarrow$ можно найти скорость света, если удалось подобрать частоту вращения.
#
# <br>
#
# \begin{align}
#     &\nu\;=\;\dfrac{\omega}{2\pi};\; \Delta \varphi \;=\;\dfrac{2\pi}{720};\; \dfrac{2L\omega}{\Delta \varphi}\;=\; c, \nonumber \\
#     &\Rightarrow \;c\;=\;\dfrac{2L\cdot 720}{2\pi}\cdot 2\pi \nu \;=\; 1440L \nu. \nonumber
# \end{align}
#
# <br>
#
# $\nu \; \approx \; 24$Гц
#
# Получил: 312000 $\frac{\text{км}}{\text{с}}$
#
# Пусть луч параллелен скорости Земли.
#
# 1)
#
# <br>
#
# \begin{align}
#     & t_{r1}=t_1 + t_2 = \dfrac{L_1}{c-v_3} + \dfrac{L_1}{c+v_3},
#     \\
#     & t_{r\perp} = L_1 \dfrac{2c}{c^2 - v_3 ^2} = \boxed{\dfrac{2L_1}{c}\cdot \dfrac{1}{1-\dfrac{v_3 ^2}{c^2}}} \approx \dfrac{2L_1}{c} \cdot (1+ \dfrac{v_3 ^2}{c^2}).
# \end{align}
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/117.png" width="400" align="center"/>
#         <figcaption>Рис. 16.3: Ход луча.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# 2)
#
# <br>
#
# \begin{align}
#     & t_{r2} = t'_1 + ... = 2t'_1 = \dfrac{2L_2}{c} = \dfrac{2}{c}\sqrt{L_1 ^2 + \bigg( \dfrac{v_3 t_{r2}}{2} \bigg) ^2},
#     \\
#     & \Rightarrow t_{r2} ^2 = \dfrac{4}{c^2} \bigg(L_1 ^2 + \dfrac{v_3 ^2 t_{r2} ^2}{4}\bigg),
#     \\
#     & \Rightarrow t_{r2} ^2 \bigg(1 - \dfrac{4v_3 ^2}{4c^2}\bigg)=\dfrac{4L_1 ^2}{c^2},
#     \\
#     & \boxed{t_{r2} = \dfrac{2L_1}{c\sqrt{1-\dfrac{v_3 ^2}{c^2}}}} \approx \dfrac{2L_1 ^2}{c} \bigg( 1+\dfrac{v_3 ^2}{2c^2} \bigg).
# \end{align}
#
# <br>
#
# Положение полос в конкретной точке экрана интерферометра зависит от разности фаз когерентных волн, пришедших в эту точку. Фазу световой волны можно записать следующим образом : $\varphi=\omega t-\vec k\cdot \vec r$, где $k=\dfrac{2\pi}{\lambda}$  - волновой вектор. Таким образом, разность фаз будет зависеть от разности времён, которые затрачивают два разных световых луча до попадания на детектор.
#
# Если бы эфирный ветер существовал, то меняя ориентацию интерферометра, мы изменяли бы разность фаз когерентных световых волн в каждой точке пространства, то есть при повороте интерферометра мы наблюдали бы различную интерференционную картину (наблюдаемые нами линии в таком случае поплыли бы), но этого не было обнаружено.
#
# <br>
#
# \begin{align}
#     \Delta t = t_{r\perp} - t_{r2} = \dfrac{L_1}{c} \cdot \dfrac{v_3 ^2}{c^2}.
# \end{align}
#
# <br>
#
# Задаёт разность хода.
#
# <br>
#
# \begin{align}
#     \Delta \lambda = c \Delta t.
# \end{align}
#
#  Альберт Майкельсон 1926 г.
#
#  Улучшим опыт Фуко:
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/118.1.png" width="350" align="center"/>
#         <figcaption>Рис. 16.4: Опыт Физо.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# Характерные расстояния: $ \sim30 $ км.
#
# <br>
#
# \begin{align}
#     c = 299895 \pm 30 \dfrac{\text{км}}{\text{с}}.
# \end{align}
#
# ## Эксперимент Майкельсона и Морли.
# 1881 г. - обнаружение движения Земли относительно эфира.
#
# Самое простое:
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/118.2.png" width="350" align="center"/>
#         <figcaption>Рис. 16.5: Движение Земли.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# Пусть есть эфир, движемся ли мы относительно него?
#
# Теория эфира предполагает существование эфира, как особого вещества, которое заполняет пространство и служит средой для распространения электромагнитного и гравитационного взаимодействий.
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/118.3.png" width="400" align="center"/>
#         <figcaption>Рис. 16.6: Ход луча. Теория эфира.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# Все эксперименты выше вели к тому, что от теории эфира надо было отказываться.\\
# Теперь вспомним ряд мысленных экспериментов, чтобы получить некоторые следствия к которым нас ведёт СТО (её постулаты).
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/119.1.png" width="400" align="center"/>
#         <figcaption>Рис. 16.7: Движение света в движущемся вагоне.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# 1) Со стороны наблюдателя **в вагоне**: свет дойдёт до переднего и заднего концов вагона одновременно.
# 2) Со стороны наблюдателя **вне вагона**: хоть скорость света всё ещё $c$, но вагон тоже движется $\implies$ $t_1 = \dfrac{L}{c+v}$ и $t_2 = \dfrac{L}{c-v}$.
# Из постоянства скорости света $\implies$ $ct_2=L+vt_2$.
# В этот момент должно закрасться подозрение, что понятие одновременности событий является относительным.
# Намёк на то, что и время должно как-то преобразовываться.
# ## Изменение интервалов времени и длин
# Рассмотрим световые часы: 2 зеркала без потерь энергии.
#
# <br>
#
# \begin{align*}
#     \tau_0=\dfrac{2l}{c}.\\
# \end{align*}
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/120.1.png" width="300" align="center"/>
#         <figcaption>Рис. 16.8: Ход светового луча в световых часах.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# Пусть часы движутся вдоль оси $OX$:
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/120.2.png" width="450" align="center"/>
#         <figcaption>Рис. 16.9: Движение закреплённых световых часов.</figcaption>
#     </center>
# </figure>
#
# $\tau_0$ $\;-\;$ период в системе $K'$. Чему равен период в системе $K$?
#
# <br>
#
# Вид в $K$:
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/120.3.png" width="300" align="center"/>
#         <figcaption>Рис. 16.10: Проходимый путь глазами наблюдателя из системы $K$.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# \begin{align}
#     &\left(\dfrac{v\tau}{2}\right)^2 + l^2 = \left(\dfrac{c\tau}{2}\right)^2  \implies\nonumber\\
#     &\implies \underline{\tau} = \dfrac{2l}{c} \cdot \dfrac{1}{\sqrt{1-\dfrac{v^2}{c^2}}} = \dfrac{\tau_0}{\sqrt{1 - \dfrac{v^2}{c^2}}} \quad\underline{> \tau_0}.
# \end{align}
#
# <br>
#
# Таким образом этот процесс займёт больше времени (эффект замедления).
# Переворачиваем часы (направление оси с часами).
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/121.1.png" width="400" align="center"/>
#         <figcaption>Рис. 16.11: То же движение световых часов, но повернули ось с часами.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# $\tau_0 = \dfrac{2l_0}{c}$ $\;-\;$ в системе $K'$.
# $\tau$ $\;-\;$ ?
#
# <br>
#
# \begin{align}
#     &\begin{cases}
#         t_1c=l+vt_1,\\
#         l=t_2c+vt_2.
#     \end{cases} \nonumber\\
#     &t_1 = \dfrac{l}{c-v}; \qquad t_2=\dfrac{l}{c+v} \implies \tau = t_1+t_2\nonumber\\
#     &\underline{\tau = \dfrac{2l}{c}\dfrac{1}{1-\dfrac{v^2}{c^2}}}\nonumber\\
#     &\tau = \dfrac{2l_0}{c}\dfrac{1}{\sqrt{1-\dfrac{v^2}{c^2}}} \implies \nonumber\\
#     &\implies \boxed{l = l_0 \sqrt{1-\left(\dfrac{v}{c}\right)^2}}.
# \end{align}
#
# <br>
#
# $\implies$ Длина, которую видит наблюдатель в $K$ меньше той, которую имеет объект в системе, где он покоится!
# ## Синхронизация часов
# Выполним процедуру синхронизации.
#
# <br>
#
# <figure>
#     <center>
#     <img src="pics/122.1.png" width="400" align="center"/>
#         <figcaption>Рис. 16.12: Синхронизация часов.</figcaption>
#     </center>
# </figure>
#
# <br>
#
# Часы в точке $O$ показывают $t_1$ и $t_2$.
# Так как время полёта луча в одну сторону $\dfrac{t_2-t_1}{2} \implies$ то если мы отправляем из $O$ сигнал с $t_1$, то в $A$ надо установить $t_1 + \dfrac{t_2-t_1}{2}=\dfrac{t_2+t_1}{2}$. Т.е. в 1-й раз можно измерить и найти $\Delta t = \dfrac{t_2-t_1}{2}$.
# В момент $t_3$ ещё раз отправить сигнал: в нём должна быть зашита информация $t_3 + \Delta t$. Такое время должно быть установлено на часах $A$ в момент получения сигнала.
